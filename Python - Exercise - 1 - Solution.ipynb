# %% [markdown]
# #Python - Non-technical introduction
#
# ##SOLUTION Exercise Session: "Life is easy when using the right tools: Why and how to work with Python?"
#
# This file provides the solutions to the exercises accompanying the lectures.
#
# *Note:* If you want to make changes to this document, you need to save your own copy using the "Save copy in Drive" command in the "File" menu.

# %% [markdown]
# ###01 - Getting started with Python

# %% [markdown]
# No exercises for this Unit.

# %% [markdown]
# ###02 - Understanding and using code notebooks

# %% [markdown]
# 1. Create a new Jupyter Notebook on Google Colab: [Google Colab](https://colab.research.google.com/)

# %% [markdown]
# 2. Add a simple formula (e.g. 1+1) in the first code cell of the notebook and run the code chunk (i.e. press the “play” button on the left hand side of the code cell or use the shortcut “Ctrl + ENTER” [Windows] or “Cmd + ENTER” [Mac] ).

# %% [markdown]
# 3. Insert a new text cell and add a brief description.

# %% [markdown]
# 4. Store your notebook with a meaningful name.

# %% [markdown]
# ###03 - Filling your notebook with code and text

# %% [markdown]
# 1. Recreate the following notebook: ![03-Notebook.png](data:image/png;base64,...)

# %% [markdown]
# ###04 - Advanced features of code notebooks

# %% [markdown]
# No exercises for this unit.

# %% [markdown]
# ###05 - Working with a local code editor

# %% [markdown]
# No exercises for this unit.

# %% [markdown]
# ###06 - Installing and using Python packages

# %% [markdown]
# 1. Import the Python package pandas with the alias pd.

# %%
import pandas as pd

# %% [markdown]
# 2. Find and use a Python command to list all installed packages. *Hint: Use pip but replace “install” with another command.*

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.8.1
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.2.10
# astor                         0.8.1
# astropy                       4.0.1.post1
# astunparse                    1.6.3
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.1.0
# audioread                     2.1.8
# autograd                      1.3
# Babel                         2.8.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.1.5
# blis                          0.4.1
# bokeh                         2.1.1
# boto                          2.49.0
# boto3                         1.14.48
# botocore                      1.17.48
# ...

# %% [markdown]
# 3. Have a look at the help file for the Python command `pd.read.csv`. What are optional arguments when loading a package?

# %%
#Have a look at the help file of the Pandas package.
help(pd)
#Have a look at the function read_csv of this package.
help(pd.read_csv)
#Solution: Functions reads CSV (comma-separated) file into DataFrame.
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %% [markdown]
# ###07 - Getting help

# %% [markdown]
# 1. Find out how to update to the latest Python version using conda.

# %% [markdown]
# https://stackoverflow.com/questions/45197777/how-do-i-update-anaconda

# %% [markdown]
# 2.	What is the difference between pip and conda? You can find the answers in Stackoverflow.

# %% [markdown]
# https://stackoverflow.com/questions/20994716/what-is-the-difference-between-pip-and-conda
